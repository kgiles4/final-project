# %%
#final project indexing and selecting data Katelyn Giles 
import geopandas as gdb

# %%
shelby= gdb.read_file(r"C:\Users\brige\Downloads\Shelby.gdb\Shelby.gdb", layer='County_shelby')
shelby.plot()
# Out:
# <AxesSubplot:>

# %%
southernShelby=shelby.cx[:, :0]

# %%
southernShelby.plot(figsize=(15, 5))
# Out:
# <AxesSubplot:>
