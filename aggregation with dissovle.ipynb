# %%
import geopandas as gdb

# %%
shelbyCounty=gdb.read_file(r"C:\Users\brige\Downloads\Shelby.gdb\Shelby.gdb", layer='County_shelby')
shelbypark=gdb.read_file(r"C:\Users\brige\Downloads\Shelby.gdb\Shelby.gdb", layer='Parks_shelby')
shelbyCounty.plot()
shelbypark.plot()
# Out:
# <AxesSubplot:>

# %%
shelbyparks=shelbypark[['geometry','NAME']]
shelbyparks.plot()
# Out:
# <AxesSubplot:>

# %%
spdiss=shelbyparks.dissolve(by='NAME', aggfunc='first')
spdiss.plot()
# Out:
# <AxesSubplot:>

# %%
spdiss.head()
# Out:
#                                                                    geometry
# NAME
# A. E. Beaty Park          POLYGON ((834036.931 349496.158, 834036.087 34...
# Alcy-Samuels Park         POLYGON ((774416.589 296157.881, 774454.707 29...
# Alcy-Warren Park          POLYGON ((767278.154 295663.972, 767256.625 29...
# American Way Park         POLYGON ((797859.750 292152.156, 797861.375 29...
# Arlington Sports Complex  POLYGON ((869511.157 364791.240, 869510.340 36...
