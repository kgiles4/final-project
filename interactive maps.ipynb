# %%
import geopandas as gdb

# %%
shelbyCounty=gdb.read_file(r"C:\Users\brige\Downloads\Shelby.gdb\Shelby.gdb", layer='County_shelby')
shelbypark=gdb.read_file(r"C:\Users\brige\Downloads\Shelby.gdb\Shelby.gdb", layer='Parks_shelby')

# %%
shelbyCounty.plot()
shelbypark.plot()
# Out:
# <AxesSubplot:>

# %%
shelbyCounty.explore()
shelbypark.explore()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11084/3997768654.py in <module>
# ----> 1 shelbyCounty.explore()
#       2 shelbypark.explore()
#
# ~\anaconda3\envs\geo_env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'GeoDataFrame' object has no attribute 'explore'

# %%
shelbypark.explore(
     column="Size", 
     tooltip="Size",
     popup=True, 
     tiles="CartoDB positron", 
     cmap="Set1", 
     style_kwds=dict(color="black")
    )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11084/2630547874.py in <module>
# ----> 1 shelbypark.explore(
#       2      column="Size",
#       3      tooltip="Size",
#       4      popup=True,
#       5      tiles="CartoDB positron",
#
# ~\anaconda3\envs\geo_env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'GeoDataFrame' object has no attribute 'explore'
