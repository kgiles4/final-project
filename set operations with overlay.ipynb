# %%
import geopandas as gdb

# %%
shelbyCounty=gdb.read_file(r"C:\Users\brige\Downloads\Shelby.gdb\Shelby.gdb", layer='County_shelby')
shelbypark=gdb.read_file(r"C:\Users\brige\Downloads\Shelby.gdb\Shelby.gdb", layer='Parks_shelby')
shelbyCounty.plot()
shelbypark.plot()
# Out:
# <AxesSubplot:>

# %%
shelbyCounty = shelbyCounty[['geometry']]

# %%
shelbyCounty = shelbyCounty.to_crs('epsg:3395')

# %%
shelbyCounty.plot()
# Out:
# <AxesSubplot:>

# %%
shelbypark = shelbypark.to_crs('epsg:3395')

# %%
shelbypark.plot()
# Out:
# <AxesSubplot:>

# %%
shelbyCountybuff= shelbyCounty.buffer(5000)
shelbyCountybuff.plot()
# Out:
# <AxesSubplot:>

# %%
shelbyparkbuff=shelbypark.buffer(5000)
shelbyparkbuff.plot()
# Out:
# <AxesSubplot:>

# %%
shelbyCounty_cores = shelbyCounty.overlay(capitals, how='intersection')

shelbyCounty_cores.plot(alpha=0.5, edgecolor='k', cmap='tab10');
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19304/3645288465.py in <module>
# ----> 1 shelbyCounty_cores = shelbyCounty.overlay(capitals, how='intersection')
#       2
#       3 shelbyCounty_cores.plot(alpha=0.5, edgecolor='k', cmap='tab10');
#
# ~\anaconda3\envs\geo_env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'GeoDataFrame' object has no attribute 'overlay'
